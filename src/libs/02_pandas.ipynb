# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s_int = s.astype(pd.Int64Dtype())
s_int
# Out:
# 0       1
# 1       3
# 2       5
# 3    <NA>
# 4       6
# 5       8
# dtype: Int64

# %%
s_str = s.astype(pd.StringDtype())
s_str
# Out:
# 0     1.0
# 1     3.0
# 2     5.0
# 3    <NA>
# 4     6.0
# 5     8.0
# dtype: string

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.106427 -0.059605  1.125029  0.821408
# 2013-01-02 -0.507494 -0.252651 -1.667531  0.100110
# 2013-01-03  1.855433 -0.240452 -0.637625  0.450754
# 2013-01-04  2.480195 -0.122341  0.813644  0.605235
# 2013-01-05  0.619174 -1.881900  0.376804 -1.125097
# 2013-01-06  0.061914 -0.645630 -0.879577 -0.265155

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.date_range("20130101", periods=4),
        "C": pd.Series(1, index=list(range(4)), dtype=pd.Float64Dtype()),
        "D": np.array([3] * 4, dtype=np.int32),
        "E": pd.Categorical(["car", "train", "airplane", "boat"]),
        "F": "foo"
    }
)

df2
# Out:
#      A          B    C  D         E    F
# 0  1.0 2013-01-01  1.0  3       car  foo
# 1  1.0 2013-01-02  1.0  3     train  foo
# 2  1.0 2013-01-03  1.0  3  airplane  foo
# 3  1.0 2013-01-04  1.0  3      boat  foo

# %%
#DF2 index
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
#DF index
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.567132 -0.533763 -0.144876  0.097876
# std    1.380805  0.691250  1.086705  0.711744
# min   -1.106427 -1.881900 -1.667531 -1.125097
# 25%   -0.365142 -0.547385 -0.819089 -0.173839
# 50%    0.340544 -0.246552 -0.130411  0.275432
# 75%    1.546369 -0.151869  0.704434  0.566614
# max    2.480195 -0.059605  1.125029  0.821408

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -1.106427   -0.507494    1.855433    2.480195    0.619174    0.061914
# B   -0.059605   -0.252651   -0.240452   -0.122341   -1.881900   -0.645630
# C    1.125029   -1.667531   -0.637625    0.813644    0.376804   -0.879577
# D    0.821408    0.100110    0.450754    0.605235   -1.125097   -0.265155

# %%
df["A"]
# Out:
# 2013-01-01   -1.106427
# 2013-01-02   -0.507494
# 2013-01-03    1.855433
# 2013-01-04    2.480195
# 2013-01-05    0.619174
# 2013-01-06    0.061914
# Freq: D, Name: A, dtype: float64

# %%
df[:2]
# Out:
#                    A         B         C         D
# 2013-01-01 -1.106427 -0.059605  1.125029  0.821408
# 2013-01-02 -0.507494 -0.252651 -1.667531  0.100110

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -0.507494 -0.252651
# 2013-01-03  1.855433 -0.240452
# 2013-01-04  2.480195 -0.122341

# %%
df.at[dates[0], "A"]
# Out:
# np.float64(-1.106427453702386)

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("20130101", periods=1000))

ts.plot()
# Out:
# <Axes: >

# %%
ts = ts.cumsum()

ts.plot()
# Out:
# <Axes: >

# %%
pd.
